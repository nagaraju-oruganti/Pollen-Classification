# %%
# %%capture
from google.colab import drive
drive.flush_and_unmount()
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/freelance/pollen_classification/src

# %%
from helper_config import Config
from helper_trainer import train

config = Config()
config.data_dir = '../inputs/data'
config.models_dir = '../models'
config.model_name = 'aug_0.5_v2'
config.centered_zero = True
config.train_batch_size = 8
config.iters_to_accumlate = 1
config.learning_rate = 5e-5
config.num_epochs = 100

# augmentation
config.aug_threshold = 0.5           # % of sample in train dataset get augmented
config.max_rotation_angle = 135

results = train(config)
# Out:
# set seed to 3407
# 100%|█████████████████████████████████████████████████████████████| 90/90 [01:25<00:00,  1.05it/s, batch_loss=1.116292, epoch_loss=1.058336, learning_rate=5e-5]
# >>> [2023-08-03 09:58:47.208607 | 1/100 | Early stopping counter 0]
#     loss          - train: 0.937215      valid: 0.930800
#     f1-score      - train: 0.526276      valid: 0.579083
#     accuracy      - train: 0.582173      valid: 0.608333
#     learning rate        : 5.00000e-05
# 100%|█████████████████████████████████████████████████████████████| 90/90 [01:24<00:00,  1.06it/s, batch_loss=0.302999, epoch_loss=0.818210, learning_rate=5e-5]
# >>> [2023-08-03 10:01:56.011582] - Checkpoint and predictions saved
#
# >>> [2023-08-03 10:01:56.012887 | 2/100 | Early stopping counter 0]
#     loss          - train: 0.758247      valid: 0.686004
#     f1-score      - train: 0.634939      valid: 0.711908
#     accuracy      - train: 0.658774      valid: 0.725000
#     learning rate        : 5.00000e-05
# ...
