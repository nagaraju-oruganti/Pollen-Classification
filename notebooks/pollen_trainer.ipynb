# %%
# %%capture
from google.colab import drive
drive.flush_and_unmount()
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/freelance/pollen_classification/src

# %%
from helper_config import Config
from helper_trainer import train

config = Config()
config.data_dir = '../inputs/data'
config.models_dir = '../models'
config.model_name = 'aug_1.0'
config.train_batch_size = 8
config.iters_to_accumlate = 1
config.learning_rate = 5e-5
config.num_epochs = 100

# augmentation
config.aug_threshold = 1           # % of sample in train dataset get augmented

results = train(config)
# Out:
# set seed to 3407
# 100%|███████████████████████████████████████████████████████████| 120/120 [01:46<00:00,  1.12it/s, batch_loss=1.127686, epoch_loss=1.121372, learning_rate=5e-5]
# >>> [2023-08-03 07:49:48.800106 | 1/100 | Early stopping counter 0]
#     loss          - train: 1.099103      valid: 1.098851
#     f1-score      - train: 0.200859      valid: 0.231131
#     accuracy      - train: 0.350000      valid: 0.366667
#     learning rate        : 5.00000e-05
# 100%|███████████████████████████████████████████████████████████| 120/120 [01:44<00:00,  1.14it/s, batch_loss=1.055176, epoch_loss=1.093546, learning_rate=5e-5]
# >>> [2023-08-03 07:53:23.769254 | 2/100 | Early stopping counter 1]
#     loss          - train: 1.082704      valid: 1.078276
#     f1-score      - train: 0.173699      valid: 0.166667
#     accuracy      - train: 0.336458      valid: 0.333333
#     learning rate        : 5.00000e-05
# 100%|███████████████████████████████████████████████████████████| 120/120 [01:44<00:00,  1.15it/s, batch_loss=1.087952, epoch_loss=1.066997, learning_rate=5e-5]
# >>> [2023-08-03 07:57:04.667714] - Checkpoint and predictions saved
#
# >>> [2023-08-03 07:57:04.668042 | 3/100 | Early stopping counter 0]
#     loss          - train: 1.033446      valid: 1.012940
#     f1-score      - train: 0.554839      valid: 0.639762
#     accuracy      - train: 0.566667      valid: 0.650000
#     learning rate        : 5.00000e-05
#  99%|██████████████████████████████████████████████████████████▌| 119/120 [01:47<00:00,  1.03it/s, batch_loss=1.010376, epoch_loss=1.001333, learning_rate=5e-5]
